# %%
import pandas as pd
df_first = pd.read_csv('03_10_2022_category-main_first_full.csv',on_bad_lines='skip', sep='\t')
# df_second = pd.read_csv ('26_09_2022_category-main_second_full.csv',on_bad_lines='skip', sep='\t')

# %%
# df_second=df_second.drop(['Unnamed: 0'], axis=1)
df_first=df_first.drop(['Unnamed: 0'], axis=1)

# %%
df_first
# Out:
#       item_id  book_instance  \
# 0       Q1044            222
# 1    Q1048340              0
# 2    Q1048918              1
# 3       Q1049             54
# 4    Q1072140              2
# ..        ...            ...
# 125      Q878            216
# 126      Q912             27
# 127      Q916             12
# 128   Q950644              1
# 129   Q950644              1
#
#      reports_policy_legislation_and_technical_documentation_instance  \
# 0                                                   90
# 1                                                    0
# 2                                                    0
# 3                                                   87
# 4                                                    0
# ..                                                 ...
# 125                                                 96
# 126                                                 93
# 127                                                  6
# ...

# %%
# df_second

# %%
df_full = df_first

# %%
df_full
# Out:
#       item_id  book_instance  \
# 0       Q1044            222
# 1    Q1048340              0
# 2    Q1048918              1
# 3       Q1049             54
# 4    Q1072140              2
# ..        ...            ...
# 125      Q878            216
# 126      Q912             27
# 127      Q916             12
# 128   Q950644              1
# 129   Q950644              1
#
#      reports_policy_legislation_and_technical_documentation_instance  \
# 0                                                   90
# 1                                                    0
# 2                                                    0
# 3                                                   87
# 4                                                    0
# ..                                                 ...
# 125                                                 96
# 126                                                 93
# 127                                                  6
# ...

# %%
df_full = df_full.drop_duplicates()

# %%
df_full
# Out:
#       item_id  book_instance  \
# 0       Q1044            222
# 1    Q1048340              0
# 2    Q1048918              1
# 3       Q1049             54
# 4    Q1072140              2
# ..        ...            ...
# 125      Q878            216
# 126      Q912             27
# 127      Q916             12
# 128   Q950644              1
# 129   Q950644              1
#
#      reports_policy_legislation_and_technical_documentation_instance  \
# 0                                                   90
# 1                                                    0
# 2                                                    0
# 3                                                   87
# 4                                                    0
# ..                                                 ...
# 125                                                 96
# 126                                                 93
# 127                                                  6
# ...

# %%
df_full.rename(columns={'book_instance': 'book', 'reports_policy_legislation_and_technical_documentation_instance': 'reports_policy_legislation'\
                       , 'databases_instance': 'databases','book_instance': 'book','academic_scientific': 'Academic',\
                        'news_media_sources': 'news_media'}, inplace=True)

# %%
df_full
# Out:
#       item_id  book  reports_policy_legislation  databases  Academic  \
# 0       Q1044   222                          90        327         0
# 1    Q1048340     0                           0          7         0
# 2    Q1048918     1                           0          1         0
# 3       Q1049    54                          87        324        18
# 4    Q1072140     2                           0          2         0
# ..        ...   ...                         ...        ...       ...
# 125      Q878   216                          96        318         0
# 126      Q912    27                          93        207         3
# 127      Q916    12                           6         33         9
# 128   Q950644     1                           0          6         0
# 129   Q950644     1                           0          6         0
#
#      news_media  wiki            category            Item label   Item ID  \
# ...

# %%
df_full.groupby('category').count()
# Out:
#                     item_id  book  reports_policy_legislation  databases  \
# category
# country                  93    93                          93         93
# disputed_territory       37    37                          37         37
#
#                     Academic  news_media  wiki  Item label  Item ID  \
# category
# country                   93          93    93          90       93
# disputed_territory        37          37    37          34       37
#
#                     Weighted ORES Score
# category
# country                              93
# disputed_territory                   37

# %%
df_full.groupby('category').count().plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %%
df_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki' ]].sum()
# Out:
# Academic                        78
# book                          2250
# reports_policy_legislation    1296
# databases                     5023
# news_media                      34
# wiki                           531
# dtype: int64

# %%
df_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki' ]].sum().plot(kind='bar', title='Wikidata References', ylabel='Sum of References',
         xlabel='Categories', figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Wikidata References'}, xlabel='Categories', ylabel='Sum of References'>

# %%
import matplotlib.pyplot as plt
sizes=df_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki' ]].sum()
explode = (0, 0, 0, 0, 0, 0)
labels='Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki'

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, radius = 2.3,)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df_country=df_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki', 'category' ]].groupby('category').get_group('country')

# %%
df_disputed_territory=df_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki', 'category' ]].groupby('category').get_group('disputed_territory')

# %%
# import matplotlib.pyplot as plt
sizes_count=df_country[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki']].sum()
explode = (0, 0, 0, 0, 0, 0)
labels='Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki'

fig1, ax1 = plt.subplots()
ax1.pie(sizes_count, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, radius = 2.3,)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# import matplotlib.pyplot as plt
sizes_dis_count=df_disputed_territory[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki']].sum()
explode = (0, 0, 0, 0, 0, 0)
labels='Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki'

fig1, ax1 = plt.subplots()
ax1.pie(sizes_dis_count, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, radius = 2.3,)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
 df_full['Weighted ORES Score'].mean()
# Out:
# 3.282769230769229

# %%
df_full.groupby('category').mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %%
df_full.groupby('category')['Academic'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %%
dfg = df_full.groupby(['category']).mean()
dfg.plot(kind='bar', title='Wikidata References', ylabel='Mean',
         xlabel='Categories', figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Wikidata References'}, xlabel='Categories', ylabel='Mean'>

# %%
# dfg = df_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki','category' ]].groupby(['category']).get_group(("animal")).mean()
# dfg#.plot(kind='bar', title='Wikidata References', ylabel='Mean',
#     #     xlabel='Categories', figsize=(15, 10))

# %%
df_full.groupby('category')[['Weighted ORES Score']].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %%
df_full.groupby('category')[['Academic']].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %%
df_full.groupby('category')['Academic'].mean()#['animal']
# Out:
# category
# country               0.774194
# disputed_territory    0.162162
# Name: Academic, dtype: float64

# %%
sizes=df_full.columns
plot = df_full.groupby('category').mean().plot.pie(subplots=True, labels=sizes, figsize=(27, 27))
# Out:
# C:\Users\disma\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1616: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)

# %%
import matplotlib.pyplot as plt

sizes=df_full.groupby('category').mean()['book']
explode = (0, 0)
labels= 'Country', 'Disputed_territory'

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
sizes=df_full.groupby('category').mean()['Academic']
explode = (0, 0.1)
labels= 'Country', 'Disputed_territory'

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# C:\Users\disma\AppData\Local\Temp/ipykernel_30264/2314786069.py:6: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',

# %%
# import matplotlib.pyplot as plt

# # sizes=df_full.groupby('category').mean()['reports_policy_legislation_and_technical_documentation_instance']

# country=df_full.groupby('category')['reports_policy_legislation'].mean()['country']
# disputed_territory=df_full.groupby('category')['reports_policy_legislation'].mean()['disputed_territory']
# others=df_full.groupby('category')['reports_policy_legislation'].mean()['animal']+\
#     df_full.groupby('category')['reports_policy_legislation'].mean()['artefact']+\
# df_full.groupby('category')['reports_policy_legislation'].mean()['feeling']+\
# df_full.groupby('category')['reports_policy_legislation'].mean()['human']

# sizes=(country, disputed_territory, others)
# explode = (0, 0, 0)
# labels='country', 'disputed_territory', 'others'

# fig1, ax1 = plt.subplots()
# ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#         shadow=True, startangle=90)
# ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# plt.title('Percentage of usage of legally recognized references',fontsize=14)

# plt.show()

# %%
df_full.groupby('category')['databases'].mean()#.columns
# Out:
# category
# country               48.258065
# disputed_territory    14.459459
# Name: databases, dtype: float64

# %%
df_full['category'].unique()
# Out:
# array(['country', 'disputed_territory'], dtype=object)

# %%
# fig, ax = plt.subplots()

# size=0.45

# ax.pie(df_full.groupby('category')['book'].mean(), radius=2, 
#        wedgeprops=dict(width=size, edgecolor='w'))
# labels='Animal', 'Artefact', 'Country', 'Disputed_territory', 'Feeling', 'Human'
# ax.pie(df_full.groupby('category')['reports_policy_legislation'].mean(), radius=2-size, labels=labels,
#        wedgeprops=dict(width=size, edgecolor='w'))

# ax.pie(df_full.groupby('category')['Academic'].mean(), radius=2-size*2, normalize=True,labels=labels,
#        wedgeprops=dict(width=size, edgecolor='w'))

# ax.pie(df_full.groupby('category')['databases'].mean(), radius=2-size*3, labels=labels,
#        wedgeprops=dict(width=size, edgecolor='w'))
# ax.pie(df_full.groupby('category')['news_media'].mean(), radius=2-size*4, normalize=True,labels=labels,
#        wedgeprops=dict(width=size, edgecolor='w'))
# ax.pie(df_full.groupby('category')['wiki'].mean(), radius=2-size*5,labels=labels,
#        wedgeprops=dict(width=size, edgecolor='w'))

# # ax.set(aspect="equal", title='Pie plot with `ax.pie`')
# plt.title('Percentage of categorization',fontsize=24,loc='left')

# %%
import seaborn as sns
sns.pairplot(df_full)

# %%
sns.pairplot(df_full, hue="category")

# %%
sns.pairplot(df_full.loc[df_full['category'] != 'human'], hue="category")

# %%
sns.pairplot(df_full, hue="category")

# %%
sns.heatmap(df_full.corr('pearson'))
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_full.corr('spearman'))
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_full.corr('kendall'))
# Out:
# <AxesSubplot:>

# %%
df_full.corr()
# Out:
#                                 book  reports_policy_legislation  databases  \
# book                        1.000000                    0.692198   0.849865
# reports_policy_legislation  0.692198                    1.000000   0.929116
# databases                   0.849865                    0.929116   1.000000
# Academic                    0.276156                    0.486498   0.491236
# news_media                  0.412480                    0.466851   0.413844
# wiki                        0.251709                    0.321376   0.386167
# Weighted ORES Score         0.500524                    0.496482   0.550485
#
#                             Academic  news_media      wiki  \
# book                        0.276156    0.412480  0.251709
# reports_policy_legislation  0.486498    0.466851  0.321376
# databases                   0.491236    0.413844  0.386167
# Academic                    1.000000    0.233570  0.395461
# news_media                  0.233570    1.000000  0.179505
# ...

# %%
df_full.corr('kendall')#kendall
# Out:
#                                 book  reports_policy_legislation  databases  \
# book                        1.000000                    0.429507   0.522634
# reports_policy_legislation  0.429507                    1.000000   0.439429
# databases                   0.522634                    0.439429   1.000000
# Academic                    0.328645                    0.341891   0.371741
# news_media                  0.388719                    0.475441   0.337513
# wiki                        0.499303                    0.201697   0.598851
# Weighted ORES Score         0.526276                    0.418258   0.681407
#
#                             Academic  news_media      wiki  \
# book                        0.328645    0.388719  0.499303
# reports_policy_legislation  0.341891    0.475441  0.201697
# databases                   0.371741    0.337513  0.598851
# Academic                    1.000000    0.279796  0.372736
# news_media                  0.279796    1.000000  0.152626
# ...

# %%
df_full.corr().plot.bar()
# Out:
# <AxesSubplot:>

# %%
matrix = df_full.corr().round(2)
print(matrix)
# Out:
#                             book  reports_policy_legislation  databases  \
# book                        1.00                        0.69       0.85
# reports_policy_legislation  0.69                        1.00       0.93
# databases                   0.85                        0.93       1.00
# Academic                    0.28                        0.49       0.49
# news_media                  0.41                        0.47       0.41
# wiki                        0.25                        0.32       0.39
# Weighted ORES Score         0.50                        0.50       0.55
#
#                             Academic  news_media  wiki  Weighted ORES Score
# book                            0.28        0.41  0.25                 0.50
# reports_policy_legislation      0.49        0.47  0.32                 0.50
# databases                       0.49        0.41  0.39                 0.55
# Academic                        1.00        0.23  0.40                 0.40
# ...

# %%
matrix['databases'].plot.bar(figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
matrix = df_full.groupby('category').corr().round(2)
print(matrix)
# Out:
#                                                book  \
# category
# country            book                        1.00
#                    reports_policy_legislation  0.74
#                    databases                   0.86
#                    Academic                    0.25
#                    news_media                  0.46
#                    wiki                        0.21
#                    Weighted ORES Score         0.50
# disputed_territory book                        1.00
#                    reports_policy_legislation  0.89
#                    databases                   0.91
#                    Academic                    0.89
#                    news_media                  0.73
#                    wiki                        0.71
#                    Weighted ORES Score         0.58
#
#                                                reports_policy_legislation  \
# category
# country            book                                              0.74
# ...

# %%
sns.heatmap(df_full.groupby('category').corr(), center=1)
# Out:
# <AxesSubplot:ylabel='category-None'>

# %%
corr = df_full.corr()
corr.style.background_gradient(cmap='coolwarm')
plt.savefig('result.png', bbox_inches='tight', pad_inches=0.0)

# %%
df_full.corr().style.background_gradient(cmap='coolwarm')#plt.matshow()
# Out:
# <style type="text/css">
# #T_32a0e_row0_col0, #T_32a0e_row1_col1, #T_32a0e_row2_col2, #T_32a0e_row3_col3, #T_32a0e_row4_col4, #T_32a0e_row5_col5, #T_32a0e_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_32a0e_row0_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_32a0e_row0_col2 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_32a0e_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_32a0e_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_32a0e_row0_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_32a0e_row0_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_32a0e_row1_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_32a0e_row1_col2 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_32a0e_row1_col3 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_32a0e_row1_col4 {
#   background-color: #afcafc;
#   color: #000000;
# ...

# %%
# import colorsys
# import numpy as np

# df = df_full
# corr = df.groupby('category').corr()#.style.background_gradient(cmap='coolwarm')

# fig, ax = plt.subplots()
# data = corr.values
# heatmap = ax.pcolor(data, cmap=plt.get_cmap('coolwarm'), 
#                     vmin=np.nanmin(data), vmax=np.nanmax(data))
# ax.set_xticks(np.arange(data.shape[1])+0.5, minor=False)
# ax.set_yticks(np.arange(data.shape[0])+0.5, minor=False)
# ax.invert_yaxis()
# row_labels = corr.index
# column_labels = corr.columns
# ax.set_xticklabels(row_labels, minor=False)
# ax.set_yticklabels(column_labels, minor=False)

# def _annotate_heatmap(ax, mesh):
#     """
#     **Taken from seaborn/matrix.py**
#     Add textual labels with the value in each cell.
#     """
#     mesh.update_scalarmappable()
#     xpos, ypos = np.meshgrid(ax.get_xticks(), ax.get_yticks())
#     for x, y, val, color in zip(xpos.flat, ypos.flat,
#                                 mesh.get_array(), mesh.get_facecolors()):
#         if val is not np.ma.masked:
#             _, l, _ = colorsys.rgb_to_hls(*color[:3])
#             text_color = ".15" if l > .5 else "w"
#             val = ("{:.3f}").format(val)
#             text_kwargs = dict(color=text_color, ha="center", va="center")
#             # text_kwargs.update(self.annot_kws)
#             ax.text(x, y, val, **text_kwargs)

# _annotate_heatmap(ax, heatmap)
# plt.savefig('result.png', bbox_inches='tight', pad_inches=0.0)

# %%
df_full.groupby('category').corr().plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
corr = df_full.groupby('category').corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d47f4_row0_col0, #T_d47f4_row1_col1, #T_d47f4_row2_col2, #T_d47f4_row3_col3, #T_d47f4_row4_col4, #T_d47f4_row5_col5, #T_d47f4_row6_col6, #T_d47f4_row7_col0, #T_d47f4_row8_col1, #T_d47f4_row8_col3, #T_d47f4_row9_col2, #T_d47f4_row10_col1, #T_d47f4_row10_col3, #T_d47f4_row11_col4, #T_d47f4_row12_col5, #T_d47f4_row13_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d47f4_row0_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_d47f4_row0_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_d47f4_row0_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d47f4_row0_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_d47f4_row0_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_d47f4_row0_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_d47f4_row1_col0 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_d47f4_row1_col2 {
# ...

# %%
#normalization
for col in df_full.columns:
    print(col)
# Out:
# item_id
# book
# reports_policy_legislation
# databases
# Academic
# news_media
# wiki
# category
# Item label
# Item ID
# Weighted ORES Score

# %%
x=df_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki' ]].values #returns a numpy array

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x_scaled = min_max_scaler.fit_transform(x)

# %%
df_full_norm = pd.DataFrame(x_scaled)

# %%
df_full_norm.columns = ['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki' ]

# %%
df_full_norm
# Out:
#      Academic      book  reports_policy_legislation  databases  news_media  \
# 0    0.000000  0.891566                    0.508475   0.756944        0.00
# 1    0.000000  0.000000                    0.000000   0.016204        0.00
# 2    0.000000  0.004016                    0.000000   0.002315        0.00
# 3    1.000000  0.216867                    0.491525   0.750000        0.00
# 4    0.000000  0.008032                    0.000000   0.004630        0.00
# ..        ...       ...                         ...        ...         ...
# 125  0.000000  0.867470                    0.542373   0.736111        0.75
# 126  0.166667  0.108434                    0.525424   0.479167        0.00
# 127  0.500000  0.048193                    0.033898   0.076389        0.00
# 128  0.000000  0.004016                    0.000000   0.013889        0.00
# 129  0.000000  0.004016                    0.000000   0.013889        0.00
#
#          wiki
# 0    0.157895
# 1    0.052632
# 2    0.052632
# ...

# %%
df_full_norm[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki' ]].sum().plot(kind='bar', title='Wikidata References', ylabel='Sum of References',
         xlabel='Categories', figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Wikidata References'}, xlabel='Categories', ylabel='Sum of References'>

# %%
sizes=df_full_norm[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki' ]].sum()
explode = (0, 0, 0, 0, 0, 0)
labels='Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki'

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, radius = 2.3,)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
sns.heatmap(df_full_norm.corr())
# Out:
# <AxesSubplot:>

# %%
df_norm_full=df_full

# %%
df_norm_full
# Out:
#       item_id  book  reports_policy_legislation  databases  Academic  \
# 0       Q1044   222                          90        327         0
# 1    Q1048340     0                           0          7         0
# 2    Q1048918     1                           0          1         0
# 3       Q1049    54                          87        324        18
# 4    Q1072140     2                           0          2         0
# ..        ...   ...                         ...        ...       ...
# 125      Q878   216                          96        318         0
# 126      Q912    27                          93        207         3
# 127      Q916    12                           6         33         9
# 128   Q950644     1                           0          6         0
# 129   Q950644     1                           0          6         0
#
#      news_media  wiki            category            Item label   Item ID  \
# ...

# %%
# normalization test2
cols_to_norm = ['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki', 'Weighted ORES Score' ]
df_norm_full[cols_to_norm] = df_norm_full[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
df_norm_full
# Out:
#       item_id      book  reports_policy_legislation  databases  Academic  \
# 0       Q1044  0.891566                    0.508475   0.756944  0.000000
# 1    Q1048340  0.000000                    0.000000   0.016204  0.000000
# 2    Q1048918  0.004016                    0.000000   0.002315  0.000000
# 3       Q1049  0.216867                    0.491525   0.750000  1.000000
# 4    Q1072140  0.008032                    0.000000   0.004630  0.000000
# ..        ...       ...                         ...        ...       ...
# 125      Q878  0.867470                    0.542373   0.736111  0.000000
# 126      Q912  0.108434                    0.525424   0.479167  0.166667
# 127      Q916  0.048193                    0.033898   0.076389  0.500000
# 128   Q950644  0.004016                    0.000000   0.013889  0.000000
# 129   Q950644  0.004016                    0.000000   0.013889  0.000000
#
#      news_media      wiki            category            Item label   Item ID  \
# ...

# %%
dfg_norm = df_norm_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki','category' ]].groupby(['category']).mean()
dfg_norm.plot(kind='bar', title='Wikidata References', ylabel='Mean',
         xlabel='Categories', figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Wikidata References'}, xlabel='Categories', ylabel='Mean'>

# %%
df_norm_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki' ]].sum().plot(kind='bar', title='Wikidata References', ylabel='Sum of References',
         xlabel='Categories', figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Wikidata References'}, xlabel='Categories', ylabel='Sum of References'>

# %%
sizes=df_norm_full[['Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki' ]].sum()
explode = (0, 0, 0, 0, 0, 0)
labels='Academic','book', 'reports_policy_legislation', 'databases', 'news_media', 'wiki'

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, radius = 2.3,)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
sns.heatmap(df_norm_full.corr())
# Out:
# <AxesSubplot:>

# %%
df_norm_full.corr()
# Out:
#                                 book  reports_policy_legislation  databases  \
# book                        1.000000                    0.692198   0.849865
# reports_policy_legislation  0.692198                    1.000000   0.929116
# databases                   0.849865                    0.929116   1.000000
# Academic                    0.276156                    0.486498   0.491236
# news_media                  0.412480                    0.466851   0.413844
# wiki                        0.251709                    0.321376   0.386167
# Weighted ORES Score         0.500524                    0.496482   0.550485
#
#                             Academic  news_media      wiki  \
# book                        0.276156    0.412480  0.251709
# reports_policy_legislation  0.486498    0.466851  0.321376
# databases                   0.491236    0.413844  0.386167
# Academic                    1.000000    0.233570  0.395461
# news_media                  0.233570    1.000000  0.179505
# ...

# %%
matrix=df_norm_full.corr().round(2)
print(matrix)
# Out:
#                             book  reports_policy_legislation  databases  \
# book                        1.00                        0.69       0.85
# reports_policy_legislation  0.69                        1.00       0.93
# databases                   0.85                        0.93       1.00
# Academic                    0.28                        0.49       0.49
# news_media                  0.41                        0.47       0.41
# wiki                        0.25                        0.32       0.39
# Weighted ORES Score         0.50                        0.50       0.55
#
#                             Academic  news_media  wiki  Weighted ORES Score
# book                            0.28        0.41  0.25                 0.50
# reports_policy_legislation      0.49        0.47  0.32                 0.50
# databases                       0.49        0.41  0.39                 0.55
# Academic                        1.00        0.23  0.40                 0.40
# ...

# %%
df_norm_full.corr()['Weighted ORES Score'].round(2).plot(kind='bar', title='Correlation between Item Quality of Wikidata and types of the References', ylabel='Sum of References',
         xlabel='Categories', figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Correlation between Item Quality of Wikidata and types of the References'}, xlabel='Categories', ylabel='Sum of References'>
